# %% [markdown]
# # My first Jupyter Notebook in VS Code
# ## A mini project exercise
# ### __Expenses Tracker Simulation__

# %% [markdown]
# #### 1. We begin by loading data from the expenses.csv file, randomly generated from generate_expenses.py file

# %%
import pandas as pd
import pandas as pd
df = pd.read_csv("expenses.csv")
df.head()
print(df.head())
# Out:
#          Date  Amount  Category         Notes
# 0  2025-06-06  204.31    Health      Pharmacy
# 1  2025-05-24  239.96  Shopping  Train ticket
# 2  2025-05-24  116.07    Travel           Gym
# 3  2025-07-07  132.62    Travel          Uber
# 4  2025-06-02  103.99  Shopping        Coffee

# %% [markdown]
# #### 2. Cleaning the data

# %% [markdown]
# #### 3. Visualising data - Pareto of spending by Category

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group and sort by total amount
grouped = df.groupby("Category", as_index=False)["Amount"].sum()
grouped = grouped.sort_values(by="Amount", ascending=False)

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x="Category", y="Amount", data=grouped)
plt.title("Total Spend per Category (Sorted)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4. Average Spending per Category

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group and sort by total amount
grouped = df.groupby("Category", as_index=False)["Amount"].sum()
grouped = grouped.sort_values(by="Amount", ascending=False)

# Count number of entries
counts = df["Category"].value_counts().reset_index()
counts.columns = ["Category", "Number of Entries"]

# Merge to align by Category
merged = pd.merge(grouped, counts, on="Category")

# Add average column
merged["Average Amount"] = merged["Amount"] / merged["Number of Entries"]

# Print result
print(merged)

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x="Category", y="Amount", hue="Average Amount", data=merged)
plt.title("Total Spend per Category (Sorted)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#         Category   Amount  Number of Entries  Average Amount
# 0      Utilities  2583.30                 18      143.516667
# 1           Food  2332.46                 18      129.581111
# 2  Entertainment  2265.98                 17      133.292941
# 3       Shopping  2210.34                 18      122.796667
# 4         Travel  1686.12                 15      112.408000
# 5         Health  1563.12                 14      111.651429
